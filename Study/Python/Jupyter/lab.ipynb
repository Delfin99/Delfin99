# %%
import matplotlib as plt

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
plt.plot([70, 48, 71, 62, 56, 62, 71, 59, 91, 58, 60, 84, 56, 54, 47, 54, 64], 
         ['Client Server Programming', 'Cloud Computing', 'Database2', 'Mobile Sofware Programming', 
          'Software Engineering3', 'Intro to Artificial Intelligence', 'Algorithms & Data Structures', 
         'Data Communications', 'Database1', 'Human Computer Interaction', 'Legal & Professional Issue', 
         'Mathematics2', 'Object Oriented Programming', 'Operating Systems2', 'Software Engineering1', 
         'Software Engineering2', 'Web Development2'], 'b--o' )
plt.xlabel('Grade')
plt.ylabel('Module')
plt.axis([0, 100, -1, 17])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([70, 48, 71, 62, 56, 62, 71, 59, 91, 58, 60, 84, 56, 54, 47, 54, 64], 
         ['Client Server Programming', 'Cloud Computing', 'Database2', 'Mobile Sofware Programming', 
          'Software Engineering3', 'Intro to Artificial Intelligence', 'Algorithms & Data Structures', 
         'Data Communications', 'Database1', 'Human Computer Interaction', 'Legal & Professional Issue', 
         'Mathematics2', 'Object Oriented Programming', 'Operating Systems2', 'Software Engineering1', 
         'Software Engineering2', 'Web Development2'], 'b--o' )
plt.xlabel('Grade')
plt.ylabel('Module')
plt.axis([0, 100, -1, 17])
plt.show()

# %%
modules_sem_3 = ['Client Server Programming', 'Cloud Computing', 'Database2', 'Mobile Sofware Programming', 
                  'Software Engineering3', 'Intro to Artificial Intelligence']

grades_sem_3 = [70, 48, 71, 62, 56, 62]

modules_sem2_2 = ['Algorithms & Data Structures', 'Data Communications', 'Human Computer Interaction', 
                  'Legal & Professional Issue', 'Software Engineering2']
                  
grades_sem2_2 = [71, 59, 58, 60, 54]

modules_sem_2 = ['Mathematics2', 'Object Oriented Programming', 'Database1', 'Operating Systems2', 
                 'Software Engineering1', 'Web Development2']
                  
grades_sem_2 = [84, 56, 91, 54, 47, 64]               
                  

plt.figure(1, figsize = (15, 30))

plt.subplot(311)
plt.plot(modules_sem_2, grades_sem_2, 'bo')
plt.ylabel('grade')
plt.xlabel('Year 2 - Sem 1')

plt.subplot(312)
plt.plot(modules_sem2_2, grades_sem2_2, 'bo')
plt.ylabel('grade')
plt.xlabel('Year 2 - Sem 2')

plt.subplot(313)
plt.plot(modules_sem_3, grades_sem_3, 'bo')
plt.ylabel('grade')
plt.xlabel('Year 3 - Sem 1')

plt.suptitle('DIT Module Grade')

plt.show()

# %%
plt.scatter(grades_sem_3, modules_sem_3, c = np.random.randint(0, 10, 6), s = np.abs(np.random.randint(1, 100, 6)))
plt.show()
