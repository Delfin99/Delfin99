# %%
# Plot()

import matplotlib.pyplot as plt

plt.plot([3, 5, 7, 9])
plt.xlabel('Actual birth weight')
plt.ylabel('Estimated birth weight')
plt.show()

# %%
plt.plot([10, 30, 23, 40])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 7, 2, 10])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 7, 2, 10], 'gs')
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'rd')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'ch')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'bv')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'r^')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'g--o')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
import numpy as np

t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3ss)
