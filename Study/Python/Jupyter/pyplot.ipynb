# %%
# Plot()

import matplotlib.pyplot as plt

plt.plot([3, 5, 7, 9])
plt.xlabel('Actual birth weight')
plt.ylabel('Estimated birth weight')
plt.show()

# %%
plt.plot([10, 30, 23, 40])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 7, 2, 10])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 7, 2, 10], 'gs')
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'rd')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'ch')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'bv')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'r^')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
plt.plot([2, 3, 4, 5], [3, 8, 10, 12], 'g--o')
plt.axis([0, 7, 0, 21])
plt.show()

# %%
# Plotting with keyword strings

import matplotlib.pyplot as plt
import numpy as np

# Evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0, 10, 0.4)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0, 20, 1.5)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data = {'a': np.arange(50), 
       'c': np.random.randint(0, 50, 50),
       'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# x, y, colour, scalar
plt.scatter('a', 'b', c = 'c', s = 'd', data = data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
test = {'a': np.arange(50), 
        'b': np.arange(50),
        'd': 10, 
        'c': np.random.randint(0, 50, 50)}

plt.scatter('a', 'b', c = 'c', s = 'd', data = test)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
test = {'a': np.arange(50), 
        'b': np.abs(np.random.randn(50)) * 100,
        'd': 10, 
        'c': np.arange(50)}

plt.scatter('a', 'b', c = 'c', s = 'd', data = test)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
np.random.rand(50) * 100
# Out:
# array([22.99432856, 46.22565487, 95.52888315, 30.82145541, 49.87263475,
#        79.01556982, 44.98280696, 25.30278817, 95.28527011, 63.46090316,
#        74.33502818, 34.20148454, 97.35477094, 86.52996214, 56.48153185,
#        73.79823424, 76.44305099, 19.58231791, 91.90286185, 44.57091208,
#         9.69872747, 35.15930599, 59.43723738, 62.46004624, 82.71393302,
#        86.10841602,  8.24836594, 15.6077372 ,  7.17013884, 85.28006334,
#        70.88330484,  8.74895711, 39.01717611, 51.88642459, 93.84460004,
#        78.37640383, 27.66474605, 74.87372513, 25.31118621, 28.01397388,
#        22.89334152, 63.79032206, 58.8190936 , 68.00200778, 75.58945881,
#        59.13936705, 11.13235759, 63.18699347, 92.33741301, 66.48022263])

# %%
np.random.rand(50)
# Out:
# array([0.65670179, 0.0842172 , 0.91386716, 0.17088899, 0.89744779,
#        0.62142056, 0.90412582, 0.75222784, 0.33111772, 0.65791959,
#        0.32777263, 0.07501435, 0.82738765, 0.90301409, 0.34951431,
#        0.63477571, 0.07443961, 0.91247766, 0.52471669, 0.66688308,
#        0.71731195, 0.04399272, 0.69108069, 0.25262082, 0.57409131,
#        0.18777744, 0.77642964, 0.95763843, 0.71886257, 0.0294681 ,
#        0.19752388, 0.7523726 , 0.00348575, 0.61050294, 0.38450697,
#        0.21939641, 0.71806321, 0.28346119, 0.37695912, 0.05269607,
#        0.88293323, 0.98705028, 0.38311872, 0.07507529, 0.66736885,
#        0.17397379, 0.31865037, 0.7378952 , 0.28267184, 0.99279639])

# %%
np.abs(np.random.rand(50))
# Out:
# array([0.71868447, 0.39915402, 0.23452599, 0.78809858, 0.09406773,
#        0.57058372, 0.18950667, 0.82506927, 0.0514174 , 0.92735747,
#        0.57968094, 0.35769553, 0.71217995, 0.26928467, 0.13198681,
#        0.07005496, 0.68250372, 0.24690784, 0.93973189, 0.97702387,
#        0.27208416, 0.22929577, 0.17215201, 0.98512678, 0.88595758,
#        0.72189071, 0.69207552, 0.52567056, 0.93021606, 0.97553955,
#        0.7925363 , 0.38343372, 0.65305995, 0.88552846, 0.73317325,
#        0.64645495, 0.04780914, 0.9369167 , 0.68535862, 0.14828936,
#        0.18787834, 0.82731436, 0.54402738, 0.54953812, 0.20647481,
#        0.8733045 , 0.6189749 , 0.46403243, 0.46970018, 0.24934235])

# %%
# Plotting with categorial variables

names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize = (9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
plt.subplot(111)

# %%
plt.subplot(121)

# %%
plt.subplot(131)

# %%
plt.subplot(141)

# %%
plt.subplot(151)

# %%
plt.subplot(151)
plt.subplot(153)
plt.subplot(155)
plt.show()

# %%
plt.subplot(121)
plt.subplot(122)
plt.show()

# %%
plt.subplot(131)
plt.subplot(133)
plt.subplot(132)
plt.show()

# %%
plt.subplot(211)
plt.subplot(212)
plt.show()

# %%
plt.subplot(311)
# plt.subplot(312)
plt.subplot(313)
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize = (9, 9))

plt.subplot(131)
plt.bar(names, values)
plt.xlabel('bar')
plt.ylabel('values')
plt.subplot(132)
plt.scatter(names, values, c = 'r')
plt.xlabel('point')
plt.subplot(133)
plt.plot(names, values, 'g--')
plt.xlabel('line')
plt.suptitle('Categorical Plotting')

plt.figure(2, figsize = (12, 5))
plt.bar(names, values)
plt.xlabel('Test')
plt.ylabel('Y')
plt.suptitle('This is test graph')

plt.show()
